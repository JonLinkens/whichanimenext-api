# %%
import os #paths to file
import numpy as np # linear algebra
import pandas as pd # data processing
import warnings# warning filter
import scipy as sp #pivot egineering


#ML model
from sklearn.metrics.pairwise import cosine_similarity


#default theme and settings
pd.options.display.max_columns

#handle warnings
warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %%
# reading into dataframes

rating_df = pd.read_csv("rating_complete.csv.zip")

anime_df = pd.read_csv("anime.csv.zip")

# %%
rating_df.sample(1)
print(rating_df.shape)
# Out:
# (57633278, 3)

# %%
anime_df.sample(1)
print(anime_df.shape)
# Out:
# (17562, 35)

# %%
anime_df = anime_df.loc[anime_df['Type'] == 'TV']
print(anime_df.shape)
# Out:
# (4996, 35)

# %%
rating_df = rating_df.loc[rating_df['anime_id'].isin(anime_df['MAL_ID'])]
print(rating_df.shape)
# Out:
# (38541711, 3)

# %%
# only want anime, so filter the df to only be TV data (anime)
# anime_df = anime_df[anime_df['type']=='TV']

# merging the dataframes

anime1 = anime_df[['MAL_ID', 'Name', 'Score']]

rating1 = rating_df[['user_id', 'anime_id', 'rating']]


merged1 = rating_df.merge(anime1, left_on='anime_id', right_on='MAL_ID', suffixes=['_user', ''])
print(merged1.columns)
# making it only uid, name and rating
# rated_anime =rated_anime[['user_id', 'Name', 'rating']]
# Out:
# Index(['user_id', 'anime_id', 'rating', 'MAL_ID', 'Name', 'Score'], dtype='object')

# %%
rated_anime = merged1[['user_id', 'Name', 'Score']]

# %%
rated_anime.sample(20)
# Out:
#           user_id                                               Name Score
# 25777818   163200                                Seikon no Qwaser II  6.39
# 5302259    103945                        Shingeki no Kyojin Season 2  8.45
# 14420142   169411                            Kore wa Zombie Desu ka?  7.43
# 1073832    171283                                      Made in Abyss  8.74
# 30653463   147849  Shinchou Yuusha: Kono Yuusha ga Ore Tueee Kuse...  7.54
# 6069564      2931                                           Sankarea  7.36
# 11295749   226869                                            D-Frag!  7.58
# 21838099   193859                              Free!: Eternal Summer  7.68
# 8170009    248903                                          Working!!   7.7
# 21098176    32656                                    Majimoji Rurumo  6.85
# 23945354   277257                                        Overlord II  7.78
# 19597891   279836                                         Usagi Drop  8.43
# 4652746    267219                           One Punch Man 2nd Season  7.41
# 28912804   292058                                          Yuyushiki  7.38
# 16310154   321544                  Kono Minikuku mo Utsukushii Sekai  6.76
# 15688147    32921                                            Kanokon  6.46
# 2715488    272728                   Fullmetal Alchemist: Brotherhood  9.19
# 1936753    325612                            Boku dake ga Inai Machi  8.37
# 35665207   271802                                        Anne Happy♪  6.98
# 22696836   181178                                           Drifters  7.94

# %%
rated_anime = rated_anime[pd.to_numeric(rated_anime['Score'], errors='coerce').notnull()]

# %%
rated_anime['Score'] = rated_anime['Score'].astype(float)
rated_anime.dtypes
# Out:
# user_id      int64
# Name        object
# Score      float64
# dtype: object

# %%
# making a pivot table for similarity calculations

pivot = rated_anime.pivot_table(index=['user_id'], columns=['Name'], values='Score')
pivot.head()
# Out:
# Name     .hack//Roots  .hack//Sign  .hack//Tasogare no Udewa Densetsu  009-1  \
# user_id
# 0                 NaN          NaN                                NaN    NaN
# 1                 NaN          NaN                                NaN    NaN
# 2                 NaN          NaN                                NaN    NaN
# 3                 NaN          NaN                                NaN    NaN
# 4                 NaN          NaN                                NaN    NaN
#
# Name     07-Ghost  100% Pascal-sensei (TV)  \
# user_id
# 0             NaN                      NaN
# 1             NaN                      NaN
# 2             NaN                      NaN
# 3             NaN                      NaN
# 4             NaN                      NaN
#
# Name     100-man no Inochi no Ue ni Ore wa Tatteiru  11eyes  \
# user_id
# 0                                               NaN     NaN
# 1                                               NaN     NaN
# 2                                               NaN     NaN
# 3                                               NaN     NaN
# 4                                               NaN     NaN
#
# Name     12-sai.: Chicchana Mune no Tokimeki  \
# user_id
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
# Name     12-sai.: Chicchana Mune no Tokimeki 2nd Season  ...  \
# user_id                                                  ...
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                                                   NaN  ...
# 3                                                   NaN  ...
# 4                                                   NaN  ...
#
# Name     ef: A Tale of Memories.  gdMen  gdgd Fairies  gdgd Fairies 2  \
# user_id
# 0                            NaN    NaN           NaN             NaN
# 1                            NaN    NaN           NaN             NaN
# 2                            NaN    NaN           NaN             NaN
# 3                            NaN    NaN           NaN             NaN
# 4                            NaN    NaN           NaN             NaN
#
# Name     iDOLM@STER Xenoglossia  number24  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# user_id
# 0                           NaN       NaN       NaN       NaN           NaN
# 1                           NaN       NaN       NaN       NaN           NaN
# 2                           NaN       NaN       NaN       NaN           NaN
# 3                           NaN       NaN       NaN       NaN           NaN
# 4                           NaN       NaN       NaN      8.01          8.25
#
# Name     ēlDLIVE
# user_id
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 3770 columns]

# %%
# normalise values
pivot_n = pivot.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)

# convert NaN values to 0
pivot_n.fillna(0, inplace=True)

# transpose pivot and drop columns with 0 values (unrated)
pivot_n = pivot_n.T
pivot_n = pivot_n.loc[:, (pivot_n != 0).any(axis=0)]

# convert to sparse matrix so we can do similarity computation
piv_sparse = sp.sparse.csr_matrix(pivot_n.values)

# %%
# cosine similarity based on the pivot table sparse matrix
anime_similarity = cosine_similarity(piv_sparse)

# making that into a dataframe
ani_sim_df = pd.DataFrame(anime_similarity, index = pivot_n.index, columns = pivot_n.index)

# %%
# recommendation fuction
def anime_recommendation(ani_name):
    
    number = 1
    print('Recommended because you watched {}:\n'.format(ani_name))
    try:
      for anime in ani_sim_df.sort_values(by = ani_name, ascending = False).index[1:6]:
          print(f'#{number}: {anime}, {round(ani_sim_df[anime][ani_name]*100,2)}% match')
          number +=1 
    except KeyError:
      print("This anime cannot be found.")

# %%
anime_recommendation('Hunter x Hunter')
# Out:
# Recommended because you watched Hunter x Hunter:
#
# #1: Hajime no Ippo, 29.62% match
# #2: Fullmetal Alchemist, 29.05% match
# #3: Slam Dunk, 28.86% match
# #4: Yuu☆Yuu☆Hakusho, 28.53% match
# #5: Rurouni Kenshin: Meiji Kenkaku Romantan, 28.34% match

# %%
ani_sim_df.to_csv('anime_similarity.csv.gz', compression="gzip")

# %%
csv1 = pd.read_csv("anime_similarity.csv.gz")
csv1.head()
# Out:
#                                 Name  .hack//Roots  .hack//Sign  \
# 0                       .hack//Roots      1.000000     0.446023
# 1                        .hack//Sign      0.446023     1.000000
# 2  .hack//Tasogare no Udewa Densetsu      0.472166     0.449841
# 3                              009-1      0.070928     0.066707
# 4                           07-Ghost      0.091268     0.103156
#
#    .hack//Tasogare no Udewa Densetsu     009-1  07-Ghost  \
# 0                           0.472166  0.070928  0.091268
# 1                           0.449841  0.066707  0.103156
# 2                           1.000000  0.082788  0.073733
# 3                           0.082788  1.000000  0.030941
# 4                           0.073733  0.030941  1.000000
#
#    100% Pascal-sensei (TV)  100-man no Inochi no Ue ni Ore wa Tatteiru  \
# 0                 0.011659                                    0.024909
# 1                 0.010364                                    0.029923
# 2                 0.015920                                    0.024476
# 3                 0.041866                                    0.016942
# 4                -0.000850                                    0.023105
#
#      11eyes  12-sai.: Chicchana Mune no Tokimeki  ...  \
# 0  0.108471                             0.015822  ...
# 1  0.109738                             0.015573  ...
# 2  0.104293                             0.020198  ...
# 3  0.072477                             0.029891  ...
# 4  0.157014                             0.020044  ...
#
#    ef: A Tale of Memories.     gdMen  gdgd Fairies  gdgd Fairies 2  \
# 0                -0.120432  0.005148      0.009952        0.009207
# 1                -0.139168  0.007509      0.015411        0.013301
# 2                -0.130374  0.011896      0.011295        0.009816
# 3                -0.063085  0.012404      0.015194        0.010559
# 4                -0.084634 -0.001278      0.002444        0.002612
#
#    iDOLM@STER Xenoglossia  number24  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei  \
# 0                0.057498  0.007536  0.083601 -0.165894     -0.142711
# 1                0.058979  0.007760  0.151773 -0.179726     -0.150499
# 2                0.067943  0.009126  0.089539 -0.176686     -0.141359
# 3                0.044229  0.006840  0.011065 -0.104258     -0.080213
# 4                0.017835  0.024538  0.056652 -0.140468     -0.149337
#
#     ēlDLIVE
# 0  0.030586
# 1  0.028322
# 2  0.028464
# 3  0.030750
# 4  0.027444
#
# [5 rows x 3771 columns]

# %%
csv1 = csv1.set_index('Name')
csv1.head()
# Out:
#                                    .hack//Roots  .hack//Sign  \
# Name
# .hack//Roots                           1.000000     0.446023
# .hack//Sign                            0.446023     1.000000
# .hack//Tasogare no Udewa Densetsu      0.472166     0.449841
# 009-1                                  0.070928     0.066707
# 07-Ghost                               0.091268     0.103156
#
#                                    .hack//Tasogare no Udewa Densetsu  \
# Name
# .hack//Roots                                                0.472166
# .hack//Sign                                                 0.449841
# .hack//Tasogare no Udewa Densetsu                           1.000000
# 009-1                                                       0.082788
# 07-Ghost                                                    0.073733
#
#                                       009-1  07-Ghost  \
# Name
# .hack//Roots                       0.070928  0.091268
# .hack//Sign                        0.066707  0.103156
# .hack//Tasogare no Udewa Densetsu  0.082788  0.073733
# 009-1                              1.000000  0.030941
# 07-Ghost                           0.030941  1.000000
#
#                                    100% Pascal-sensei (TV)  \
# Name
# .hack//Roots                                      0.011659
# .hack//Sign                                       0.010364
# .hack//Tasogare no Udewa Densetsu                 0.015920
# 009-1                                             0.041866
# 07-Ghost                                         -0.000850
#
#                                    100-man no Inochi no Ue ni Ore wa Tatteiru  \
# Name
# .hack//Roots                                                         0.024909
# .hack//Sign                                                          0.029923
# .hack//Tasogare no Udewa Densetsu                                    0.024476
# 009-1                                                                0.016942
# 07-Ghost                                                             0.023105
#
#                                      11eyes  \
# Name
# .hack//Roots                       0.108471
# .hack//Sign                        0.109738
# .hack//Tasogare no Udewa Densetsu  0.104293
# 009-1                              0.072477
# 07-Ghost                           0.157014
#
#                                    12-sai.: Chicchana Mune no Tokimeki  \
# Name
# .hack//Roots                                                  0.015822
# .hack//Sign                                                   0.015573
# .hack//Tasogare no Udewa Densetsu                             0.020198
# 009-1                                                         0.029891
# 07-Ghost                                                      0.020044
#
#                                    12-sai.: Chicchana Mune no Tokimeki 2nd Season  \
# Name
# .hack//Roots                                                             0.013099
# .hack//Sign                                                              0.012479
# .hack//Tasogare no Udewa Densetsu                                        0.016561
# 009-1                                                                    0.028936
# 07-Ghost                                                                 0.011805
#
#                                    ...  ef: A Tale of Memories.     gdMen  \
# Name                               ...
# .hack//Roots                       ...                -0.120432  0.005148
# .hack//Sign                        ...                -0.139168  0.007509
# .hack//Tasogare no Udewa Densetsu  ...                -0.130374  0.011896
# 009-1                              ...                -0.063085  0.012404
# 07-Ghost                           ...                -0.084634 -0.001278
#
#                                    gdgd Fairies  gdgd Fairies 2  \
# Name
# .hack//Roots                           0.009952        0.009207
# .hack//Sign                            0.015411        0.013301
# .hack//Tasogare no Udewa Densetsu      0.011295        0.009816
# 009-1                                  0.015194        0.010559
# 07-Ghost                               0.002444        0.002612
#
#                                    iDOLM@STER Xenoglossia  number24  s.CRY.ed  \
# Name
# .hack//Roots                                     0.057498  0.007536  0.083601
# .hack//Sign                                      0.058979  0.007760  0.151773
# .hack//Tasogare no Udewa Densetsu                0.067943  0.009126  0.089539
# 009-1                                            0.044229  0.006840  0.011065
# 07-Ghost                                         0.017835  0.024538  0.056652
#
#                                    xxxHOLiC  xxxHOLiC Kei   ēlDLIVE
# Name
# .hack//Roots                      -0.165894     -0.142711  0.030586
# .hack//Sign                       -0.179726     -0.150499  0.028322
# .hack//Tasogare no Udewa Densetsu -0.176686     -0.141359  0.028464
# 009-1                             -0.104258     -0.080213  0.030750
# 07-Ghost                          -0.140468     -0.149337  0.027444
#
# [5 rows x 3770 columns]

# %%
animename = 'Vinland Saga'
for anime in csv1.sort_values(by=animename, ascending=False).index[1:6]:
  print(f'{anime}, {round(csv1[anime][animename]*100,2)}% match')
# Out:
# Dr. Stone, 53.57% match
# Kimetsu no Yaiba, 53.37% match
# Shingeki no Kyojin Season 3 Part 2, 52.16% match
# Shingeki no Kyojin Season 3, 50.86% match
# Yakusoku no Neverland, 50.71% match
